# %%
import numpy as np
import matplotlib.pyplot as plt

# Refroidissement
td= np.array([0,1.5,2.5,3,3.5,4,4.5,5,5.5,6,6.5,7,8,9,10,12,14,16])
Rtd=np.array([128,124,121.3,119.8,118.7,117.4,116.5,115.4,114.8,114.2,113.6,112.5,111.9,111.5,111.1,110.8,110.6,110.6])

plt.plot(td,Rtd,'+-')
plt.grid(True)
plt.show()
